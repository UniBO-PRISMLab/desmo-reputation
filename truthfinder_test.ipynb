# %%
import numpy as np
from scipy.stats import norm

# %%
data = np.array([3,4,5.5,5.3,6.7,2.4,9.9,2.2,5.5,7.7])#norm.rvs(10.0, 2.5, size=500)
data
# Out:
# array([3. , 4. , 5.5, 5.3, 6.7, 2.4, 9.9, 2.2, 5.5, 7.7])

# %%
mu, std = norm.fit(data)
mu
# Out:
# np.float64(5.220000000000001)

# %%
np.mean(data)
# Out:
# np.float64(5.220000000000001)

# %%
set(results.get_most_believed_values("x"))
# Out:
# {3.2, 3.4, 4.2, 5.5, 5.7, 6.8, 7.4, 7.6, 8.5}

# %%
results.trust
# Out:
# {'source 1': np.float64(1.0),
#  'source 2': np.float64(1.0),
#  'source 3': np.float64(1.0),
#  'source 4': np.float64(1.0),
#  'source 5': np.float64(1.0),
#  'source 6': np.float64(1.0),
#  'source 7': np.float64(1.0),
#  'source 8': np.float64(1.0),
#  'source 9': np.float64(1.0)}
